# %% [markdown]
# ## Reviewing changes in unemployment rates over time

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
unrate = pd.read_csv('unrate.csv')
unrate.head(12)
unrate.DATE = pd.to_datetime(unrate.DATE)
unrate['date'] = unrate.DATE
unrate['value'] = unrate.VALUE
unrate = unrate.drop(['DATE', 'VALUE'], axis=1)
# Out:
# Index(['DATE', 'VALUE', 'date', 'value'], dtype='object')

# %%
plt.plot(unrate.date.head(12), unrate.value.head(12))
plt.xticks(rotation=90)
plt.xlabel('Date')
plt.ylabel('Unemployment Rate')
plt.title('Monthly Unemployment Trends, 1948')
plt.show()
